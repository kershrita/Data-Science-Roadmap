# %% [markdown]
# # Hands-on Exercise
# For `Session 05 - Data Transformation`!
# In this lab session we will discuss:
#   - Handle columns distribution.
#   - Check data formats, data splitting, units, scales, etc...
#   - Data visualization using Seaborn.

# %% [markdown]
# ### Dataset Description
#
# | Label          | Description                               |
# |----------------|-------------------------------------------|
# | orbital_period | planet orbital period / stellar magnitude |
# | mass           | planet mass by (Jupiters)                 |
# | distance       | light-years from Earth                    |
# | year           | discovery date                            |
# | method         | discovery method                          |

# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-learn
#   Downloading scikit_learn-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 543.9 kB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting joblib>=1.1.1
#   Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 KB 891.9 kB/s eta 0:00:000:00:010:00:01:01
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /home/kersh/.local/lib/python3.10/site-packages (from scikit-learn) (1.26.0)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: scipy>=1.5.0 in /usr/lib/python3/dist-packages (from scikit-learn) (1.8.0)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.3.2 scikit-learn-1.3.2 threadpoolctl-3.2.0

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Collection & Exploration

# %%
df = pd.read_csv("cleaned_data.csv")
df.head()
# Out:
#    number  orbital_period   mass  distance  year           method
# 0       1         269.300   7.10     77.40  2006  Radial Velocity
# 1       1         874.774   2.21     56.95  2008  Radial Velocity
# 2       1         763.000   2.60     19.84  2011  Radial Velocity
# 3       1         326.030  19.40    110.62  2007  Radial Velocity
# 4       1         516.220  10.50    119.47  2009  Radial Velocity

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1024 entries, 0 to 1023
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   number          1024 non-null   int64
#  1   orbital_period  1024 non-null   float64
#  2   mass            1024 non-null   float64
#  3   distance        1024 non-null   float64
#  4   year            1024 non-null   int64
#  5   method          1024 non-null   object
# dtypes: float64(3), int64(2), object(1)
# memory usage: 48.1+ KB

# %%
df.hist(figsize=(12, 8), bins=20);

# %%
sns.pairplot(df);

# %%
df["orbital_period"].hist()
# Out:
# <AxesSubplot:>

# %%
np.log(df["orbital_period"]).hist()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,6))
plt.subplot(1, 2, 1)
df["orbital_period"].hist()
plt.subplot(1, 2, 2)
np.log(df["orbital_period"]).hist()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,6))
plt.subplot(1, 2, 1)
df["orbital_period"].hist()
plt.subplot(1, 2, 2)
(1/df["orbital_period"]).hist()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,6))
plt.subplot(1, 2, 1)
df["mass"].hist()
plt.subplot(1, 2, 2)
np.log(df["mass"]).hist()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,6))
plt.subplot(1, 2, 1)
df["mass"].hist()
plt.subplot(1, 2, 2)
np.sqrt(df["mass"]).hist()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,6))
plt.subplot(1, 2, 1)
df["mass"].hist()
plt.subplot(1, 2, 2)
np.cbrt(df["mass"]).hist()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,6))
plt.subplot(1, 2, 1)
df["distance"].hist()
plt.subplot(1, 2, 2)
np.log(df["distance"]).hist()
# Out:
# <AxesSubplot:>
